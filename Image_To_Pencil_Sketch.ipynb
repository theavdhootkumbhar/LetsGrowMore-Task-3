# %% [markdown]
# ## IMAGE TO PENCIL SKETCH WITH PYTHON

# %% [markdown]
# ### Importing Libraries

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image
# %matplotlib inline
print("Necessary packages included successfully!")
# Out:
# Necessary packages included successfully!

# %% [markdown]
# ### Loading the Image

# %%
image=cv2.imread("DOG.jpg")
image = cv2.resize(image,(500,300))
image
# Out:
# array([[[ 34,  38,  79],
#         [ 37,  41,  82],
#         [ 37,  42,  81],
#         ...,
#         [252, 249, 241],
#         [252, 249, 241],
#         [252, 249, 241]],
#
#        [[ 37,  42,  81],
#         [ 40,  46,  84],
#         [ 41,  47,  84],
#         ...,
#         [252, 249, 241],
#         [251, 248, 241],
#         [251, 248, 241]],
#
#        [[ 39,  45,  82],
#         [ 42,  48,  85],
#         [ 43,  49,  85],
#         ...,
#         [251, 248, 240],
#         [251, 248, 240],
#         [251, 248, 240]],
#
#        ...,
#
#        [[139, 130, 120],
#         [139, 129, 119],
#         [139, 129, 119],
#         ...,
#         [205, 200, 197],
#         [205, 200, 197],
#         [205, 200, 197]],
#
#        [[141, 132, 120],
#         [141, 132, 120],
#         [141, 132, 120],
#         ...,
#         [208, 202, 198],
#         [207, 202, 198],
#         [207, 202, 198]],
#
#        [[142, 133, 120],
#         [142, 133, 120],
#         [142, 133, 120],
#         ...,
#         [209, 203, 198],
#         [209, 203, 198],
#         [209, 203, 198]]], dtype=uint8)

# %%
img_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
plt.imshow(img_rgb)

# %% [markdown]
# ### Converting into Gray Scale

# %%
gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
gray_image
# Out:
# array([[ 50,  53,  53, ..., 247, 247, 247],
#        [ 53,  57,  57, ..., 247, 246, 246],
#        [ 55,  58,  59, ..., 246, 246, 246],
#        ...,
#        [128, 127, 127, ..., 200, 200, 200],
#        [129, 129, 129, ..., 201, 201, 201],
#        [130, 130, 130, ..., 202, 202, 202]], dtype=uint8)

# %%
plt.imshow(gray_image)

# %% [markdown]
# ### Inverting the image

# %%
inverted_image = cv2.bitwise_not(gray_image)
inverted_image
# Out:
# array([[205, 202, 202, ...,   8,   8,   8],
#        [202, 198, 198, ...,   8,   9,   9],
#        [200, 197, 196, ...,   9,   9,   9],
#        ...,
#        [127, 128, 128, ...,  55,  55,  55],
#        [126, 126, 126, ...,  54,  54,  54],
#        [125, 125, 125, ...,  53,  53,  53]], dtype=uint8)

# %%
plt.imshow(inverted_image)

# %% [markdown]
# ### Smoothing the image

# %%
img_smoothing = cv2.GaussianBlur(inverted_image, (21, 21),sigmaX=0, sigmaY=0)
img_smoothing
# Out:
# array([[190, 190, 189, ...,   9,   9,   9],
#        [190, 189, 188, ...,   9,   9,   9],
#        [188, 188, 187, ...,   9,   9,   9],
#        ...,
#        [129, 129, 129, ...,  54,  54,  54],
#        [129, 128, 128, ...,  54,  54,  54],
#        [128, 128, 128, ...,  54,  54,  54]], dtype=uint8)

# %%
plt.imshow(img_smoothing)

# %%
def dodgeV2(x, y):
    return cv2.divide(x, 255 - y, scale=256.0)

# %% [markdown]
# ### Inverting the Image to get the Pencil Sketch

# %%
pencil_sketch = dodgeV2(gray_image, img_smoothing)
plt.imshow(pencil_sketch)

# %% [markdown]
# ### Comparing the Original Image with Pencil Sketch

# %%
display(Image.fromarray(img_rgb))
display(Image.fromarray(pencil_sketch))
# Out:
# <PIL.Image.Image image mode=RGB size=500x300>
# <PIL.Image.Image image mode=L size=500x300>

# %%
cv2.imshow("Sketch", pencil_sketch)
cv2.waitKey(0)
# Out:
# -1

# %% [markdown]
# #### Conclusion: RBG format image converted into grayscale image

# %% [markdown]
# ## Thank You!
